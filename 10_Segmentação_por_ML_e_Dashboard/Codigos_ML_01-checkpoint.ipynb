# %% [markdown]
# # **Este é um teste para o projeto de ML**

# %%
print("Hello Jupyter!")

# %%
# Versão do Python
from platform import python_version
print("My python version is:", python_version())
# Out:
# My python version is: 3.13.11

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## **Carrega os dados:**

# %%
df = pd.read_csv('dados/dados_clientes.csv')

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
# Mostra o cabeçalho da tabela:
df.head()
# Out:
#    id  idade  renda_anual  pontuacao_gastos
# 0   1     56        94740                90
# 1   2     69       136352                50
# 2   3     46        86617                62
# 3   4     32       114841                97
# 4   5     60        36896                51

# %% [markdown]
# ## **Análise Exploratória**

# %%
# Resumo estatístico - bastante útil
df[['idade', 'renda_anual', 'pontuacao_gastos']].describe()
# Out:
#             idade    renda_anual  pontuacao_gastos
# count  500.000000     500.000000        500.000000
# mean    44.732000   81557.166000         48.512000
# std     15.239707   36764.379945         29.556946
# min     18.000000   20384.000000          0.000000
# 25%     32.000000   49172.750000         24.000000
# 50%     45.000000   79219.000000         48.500000
# 75%     57.000000  113017.250000         73.250000
# max     70.000000  149695.000000        100.000000

# %% [markdown]
# ## **Pré-Processamento dos Dados**

# %%
# cria o padronizar dos dados
padronizador = StandardScaler()

# %%
# Aplica o padronizador somente nas colunas de interesse
dados_padronizados = padronizador.fit_transform(df[['idade', 'renda_anual', 'pontuacao_gastos']])

# %%
# Visualização dos dados:
print(dados_padronizados)
# Out:
# [[ 0.74012478  0.35893538  1.40506904]
#  [ 1.59401387  1.49192537  0.05039391]
#  [ 0.08328703  0.13776654  0.45679645]
#  ...
#  [-0.31081563  0.32661636  0.18586143]
#  [-1.23038848 -1.48706069  1.43893592]
#  [-1.03333716 -0.96992912 -0.59307677]]

# %% [markdown]
#  ## **Construção do Modelo de Machine Learning**

# %%
# Definição do número de Clusters (k)
k = 3

# %%
# Criamos o modelo k-means
kmeans = KMeans(n_clusters = k)

# %%
# Treinamento do modelo com os dados padronizados:
kmeans.fit(dados_padronizados)
# Out:
# C:\Users\nzpai\miniconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1428: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# KMeans(n_clusters=3)

# %%
# Atribuimos os rótulos dos clusters dos clientes:
df['cluster'] = kmeans.labels_

# %%
df.sample(10)
# Out:
#       id  idade  renda_anual  pontuacao_gastos  cluster
# 452  453     19        57744                60        1
# 118  119     52       108668                89        2
# 103  104     32       109643                 2        0
# 149  150     22       105999                52        1
# 154  155     26        54911                 3        1
# 84    85     48        86387                 7        0
# 465  466     60        69922                29        0
# 360  361     55        53307                45        2
# 204  205     56       107508                63        2
# 176  177     30       139180                 3        0

# %%
# Vamos salvar o resultado do modelo:
df.to_csv('dados/segmentos_criados.csv', index = False)

# %% [markdown]
# ## **FIM!**
